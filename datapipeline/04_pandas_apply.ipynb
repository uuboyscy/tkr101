# %%
import pandas as pd

# %%
df = pd.read_csv("ptt_gossipping.csv")
df
# Out:
#           推      噓       分數                               作者  \
# 0     推: 25   噓: 4   分數: 21  作者: Rusnake5566 (魯蛇+56 PTT最強帳號)
# 1     推: 11  噓: 11    分數: 0            作者: LoveMakeLove (ボケ)
# 2     推: 20   噓: 0   分數: 20               作者: MintSu (Simon)
# 3     推: 31   噓: 2   分數: 29               作者: seiya2000 (風見)
# 4    推: 106   噓: 6  分數: 100               作者: kasumi5566 (霞)
# ..      ...    ...      ...                              ...
# 833   推: 10   噓: 1    分數: 9              作者: lockgolden (鎖金)
# 834    推: 7   噓: 0    分數: 7           作者: nothisman (在人海中迷失)
# 835    推: 0   噓: 0    分數: 0      作者: wa778895 (oilsunbright)
# 836   推: 15   噓: 4   分數: 11              作者: stan0720 (Kimo)
# 837    推: 5   噓: 0    分數: 5           作者: bigtreelife (Tree)
#
#                                  標題                            時間
# 0       標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性  時間: Fri Oct  2 13:56:39 2020
# 1      標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵  時間: Wed Oct  7 18:53:08 2020
# ...

# %%
def t_push_str_to_int(input_str: str) -> int:
    """推: 25 -> 25"""
    return int(input_str.split(":")[1].strip())

df["推"].apply(t_push_str_to_int)
# Out:
# 0       25
# 1       11
# 2       20
# 3       31
# 4      106
#       ...
# 833     10
# 834      7
# 835      0
# 836     15
# 837      5
# Name: 推, Length: 838, dtype: int64

# %%
df["推"]
# Out:
# 0       推: 25
# 1       推: 11
# 2       推: 20
# 3       推: 31
# 4      推: 106
#         ...
# 833     推: 10
# 834      推: 7
# 835      推: 0
# 836     推: 15
# 837      推: 5
# Name: 推, Length: 838, dtype: str

# %%
df["推"] = df["推"].apply(t_push_str_to_int)

# %%
df
# Out:
#        推      噓       分數                               作者  \
# 0     25   噓: 4   分數: 21  作者: Rusnake5566 (魯蛇+56 PTT最強帳號)
# 1     11  噓: 11    分數: 0            作者: LoveMakeLove (ボケ)
# 2     20   噓: 0   分數: 20               作者: MintSu (Simon)
# 3     31   噓: 2   分數: 29               作者: seiya2000 (風見)
# 4    106   噓: 6  分數: 100               作者: kasumi5566 (霞)
# ..   ...    ...      ...                              ...
# 833   10   噓: 1    分數: 9              作者: lockgolden (鎖金)
# 834    7   噓: 0    分數: 7           作者: nothisman (在人海中迷失)
# 835    0   噓: 0    分數: 0      作者: wa778895 (oilsunbright)
# 836   15   噓: 4   分數: 11              作者: stan0720 (Kimo)
# 837    5   噓: 0    分數: 5           作者: bigtreelife (Tree)
#
#                                  標題                            時間
# 0       標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性  時間: Fri Oct  2 13:56:39 2020
# 1      標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵  時間: Wed Oct  7 18:53:08 2020
# 2        標題: [問卦] 如果川普老婆死於武漢肺炎會怎麼樣？  時間: Fri Oct  2 13:30:55 2020
# ...

# %%
df["噓_t"] = df["噓"].apply(t_push_str_to_int)

# %%
df
# Out:
#        推      噓       分數                               作者  \
# 0     25   噓: 4   分數: 21  作者: Rusnake5566 (魯蛇+56 PTT最強帳號)
# 1     11  噓: 11    分數: 0            作者: LoveMakeLove (ボケ)
# 2     20   噓: 0   分數: 20               作者: MintSu (Simon)
# 3     31   噓: 2   分數: 29               作者: seiya2000 (風見)
# 4    106   噓: 6  分數: 100               作者: kasumi5566 (霞)
# ..   ...    ...      ...                              ...
# 833   10   噓: 1    分數: 9              作者: lockgolden (鎖金)
# 834    7   噓: 0    分數: 7           作者: nothisman (在人海中迷失)
# 835    0   噓: 0    分數: 0      作者: wa778895 (oilsunbright)
# 836   15   噓: 4   分數: 11              作者: stan0720 (Kimo)
# 837    5   噓: 0    分數: 5           作者: bigtreelife (Tree)
#
#                                  標題                            時間  噓_t
# 0       標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性  時間: Fri Oct  2 13:56:39 2020    4
# 1      標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵  時間: Wed Oct  7 18:53:08 2020   11
# ...

# %%
df["噓"].apply(
    lambda x: int(x.split(":")[1].strip())
)
# Out:
# 0       4
# 1      11
# 2       0
# 3       2
# 4       6
#        ..
# 833     1
# 834     0
# 835     0
# 836     4
# 837     0
# Name: 噓, Length: 838, dtype: int64

# %%
df["噓"].str.split(":")
# Out:
# 0       [噓,  4]
# 1      [噓,  11]
# 2       [噓,  0]
# 3       [噓,  2]
# 4       [噓,  6]
#          ...
# 833     [噓,  1]
# 834     [噓,  0]
# 835     [噓,  0]
# 836     [噓,  4]
# 837     [噓,  0]
# Name: 噓, Length: 838, dtype: object

# %%
df["噓"].str.split(":").str[1].astype(int)
# Out:
# 0       4
# 1      11
# 2       0
# 3       2
# 4       6
#        ..
# 833     1
# 834     0
# 835     0
# 836     4
# 837     0
# Name: 噓, Length: 838, dtype: int64

# %%
df
# Out:
#        推      噓       分數                               作者  \
# 0     25   噓: 4   分數: 21  作者: Rusnake5566 (魯蛇+56 PTT最強帳號)
# 1     11  噓: 11    分數: 0            作者: LoveMakeLove (ボケ)
# 2     20   噓: 0   分數: 20               作者: MintSu (Simon)
# 3     31   噓: 2   分數: 29               作者: seiya2000 (風見)
# 4    106   噓: 6  分數: 100               作者: kasumi5566 (霞)
# ..   ...    ...      ...                              ...
# 833   10   噓: 1    分數: 9              作者: lockgolden (鎖金)
# 834    7   噓: 0    分數: 7           作者: nothisman (在人海中迷失)
# 835    0   噓: 0    分數: 0      作者: wa778895 (oilsunbright)
# 836   15   噓: 4   分數: 11              作者: stan0720 (Kimo)
# 837    5   噓: 0    分數: 5           作者: bigtreelife (Tree)
#
#                                  標題                            時間  噓_t
# 0       標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性  時間: Fri Oct  2 13:56:39 2020    4
# 1      標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵  時間: Wed Oct  7 18:53:08 2020   11
# ...

# %%
pd.to_datetime("20260510")
# Out:
# Timestamp('2026-05-10 00:00:00')

# %%
pd.to_datetime("2026-05-10")
# Out:
# Timestamp('2026-05-10 00:00:00')

# %%
pd.to_datetime("2026/05/10")
# Out:
# Timestamp('2026-05-10 00:00:00')

# %%
pd.to_datetime("2026/05/10 10:30:44")
# Out:
# Timestamp('2026-05-10 10:30:44')

# %%
pd.to_datetime("2026-05-10T10:30:44")
# Out:
# Timestamp('2026-05-10 10:30:44')

# %%
"""Fri Oct  2 13:56:39 2020"""
pd.to_datetime("Fri Oct  2 13:56:39 2020")
# Out:
# Timestamp('2020-10-02 13:56:39')

# %%
df["時間"].str.split(":").str[1]
# Out:
# 0       Fri Oct  2 13
# 1       Wed Oct  7 18
# 2       Fri Oct  2 13
# 3       Fri Oct  2 12
# 4       Fri Oct  2 13
#             ...
# 833     Fri Oct  2 14
# 834     Wed Oct  7 21
# 835     Wed Oct  7 21
# 836     Fri Oct  2 14
# 837     Fri Oct  2 15
# Name: 時間, Length: 838, dtype: object

# %%
df["時間"].str.split(":").str[1].apply(pd.to_datetime)
# Out:
# 0     2013-10-02
# 1     2018-10-07
# 2     2013-10-02
# 3     2012-10-02
# 4     2013-10-02
#          ...
# 833   2014-10-02
# 834   2021-10-07
# 835   2021-10-07
# 836   2014-10-02
# 837   2015-10-02
# Name: 時間, Length: 838, dtype: datetime64[us]

# %%
pd.to_datetime(df["時間"].str.split(":").str[1])
# Out:
# /var/folders/_k/k5dry95j0q5d35_9pn5d86vm0000gn/T/ipykernel_77936/3856744943.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df["時間"].str.split(":").str[1])
# 0     2013-10-02
# 1     2018-10-07
# 2     2013-10-02
# 3     2012-10-02
# 4     2013-10-02
#          ...
# 833   2014-10-02
# 834   2021-10-07
# 835   2021-10-07
# 836   2014-10-02
# 837   2015-10-02
# Name: 時間, Length: 838, dtype: datetime64[us]

# %%
df["時間"].apply(
    lambda x: pd.to_datetime(
        x.split(":")[1].strip(),
    )
)
# Out:
# 0     2013-10-02
# 1     2018-10-07
# 2     2013-10-02
# 3     2012-10-02
# 4     2013-10-02
#          ...
# 833   2014-10-02
# 834   2021-10-07
# 835   2021-10-07
# 836   2014-10-02
# 837   2015-10-02
# Name: 時間, Length: 838, dtype: datetime64[us]

# %%
df["時間"].apply(
    lambda x: pd.to_datetime(
        x.split(":")[1].strip(),
    )
) >= pd.to_datetime("2021-10-01")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 833    False
# 834     True
# 835     True
# 836    False
# 837    False
# Name: 時間, Length: 838, dtype: bool

# %%
df[
    df["時間"].apply(
        lambda x: pd.to_datetime(
            x.split(":")[1].strip(),
        )
    ) >= "2022-10-01"
]
# Out:
#        推      噓       分數                   作者                         標題  \
# 216  990  噓: 66  分數: 924  作者: ubcs (覺★青年超冒險蓋)  標題: [公告] 中秋連假線上烤肉兼置底聯誼閒聊區
#
#                                時間  噓_t
# 216  時間: Wed Sep 30 23:45:49 2020   66

# %%
df["時間_t"] = df["時間"].apply(
        lambda x: pd.to_datetime(
            x.split(":")[1].strip(),
        )
    )
df
# Out:
#        推      噓       分數                               作者  \
# 0     25   噓: 4   分數: 21  作者: Rusnake5566 (魯蛇+56 PTT最強帳號)
# 1     11  噓: 11    分數: 0            作者: LoveMakeLove (ボケ)
# 2     20   噓: 0   分數: 20               作者: MintSu (Simon)
# 3     31   噓: 2   分數: 29               作者: seiya2000 (風見)
# 4    106   噓: 6  分數: 100               作者: kasumi5566 (霞)
# ..   ...    ...      ...                              ...
# 833   10   噓: 1    分數: 9              作者: lockgolden (鎖金)
# 834    7   噓: 0    分數: 7           作者: nothisman (在人海中迷失)
# 835    0   噓: 0    分數: 0      作者: wa778895 (oilsunbright)
# 836   15   噓: 4   分數: 11              作者: stan0720 (Kimo)
# 837    5   噓: 0    分數: 5           作者: bigtreelife (Tree)
#
#                                  標題                            時間  噓_t  \
# 0       標題: [問卦] 兩個候選人選前一個月同時陣亡的可能性  時間: Fri Oct  2 13:56:39 2020    4
# 1      標題: [新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵  時間: Wed Oct  7 18:53:08 2020   11
# ...

# %%
df[
    df["時間_t"] > "2021-10-01"
]
# Out:
#        推      噓       分數                                 作者  \
# 28     2   噓: 2    分數: 0                作者: jiouje (JioUje)
# 33     4   噓: 0    分數: 4           作者: hmt17 (Popo:(bﾟ▽ﾟ)b)
# 62     0   噓: 2   分數: -2                 作者: d995511 (flcl)
# 86    10   噓: 5    分數: 5            作者: stockeye (stockeye)
# 95     3   噓: 0    分數: 3                  作者: jun059 (好想睡覺)
# 163    2   噓: 0    分數: 2           作者: shala (沙羅是轉換後的文字檔打m)
# 180    6   噓: 4    分數: 2                  作者: kuro (垃圾不分藍綠)
# 216  990  噓: 66  分數: 924                作者: ubcs (覺★青年超冒險蓋)
# 219    3   噓: 0    分數: 3           作者: jason851124 (YeeeEX)
# 260    7   噓: 3    分數: 4                 作者: LineageM (天堂M)
# 299    1   噓: 1    分數: 0                作者: en5151 (asenen)
# 324    0   噓: 4   分數: -4  作者: cowboyas0413 (RAID0一時爽 資料火葬場)
# 328    1   噓: 2   分數: -1              作者: LoveMakeLove (ボケ)
# 368    5   噓: 5    分數: 0             作者: ai770116 (東方的神秘力量)
# 371    0   噓: 0    分數: 0             作者: llgod (Wryyyyyyyy)
# ...

# %%
pd.to_datetime("Wed Oct  7 21:20:19 2020")
# Out:
# Timestamp('2020-10-07 21:20:19')

# %%
"%a %b %d %H:%M:%S %Y"
pd.to_datetime("Wed Oct  7 21:20:19 2020", format="%a %b %d %H:%M:%S %Y")
# Out:
# Timestamp('2020-10-07 21:20:19')

# %%
df[
    df["時間"].apply(
        lambda x: pd.to_datetime(
            x.split(":")[1].strip(),
            format="%a %b %d %H:%M:%S %Y",
        )
    ) >= "2022-10-01"
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 df[
# ----> 2     df["時間"].apply(
#       3         lambda x: pd.to_datetime(
#       4             x.split(":")[1].strip(),
#       5             format="%a %b %d %H:%M:%S %Y",
#
# File ~/side-project/tibame/tkr101/datapipeline/.venv/lib/python3.14/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# ...
