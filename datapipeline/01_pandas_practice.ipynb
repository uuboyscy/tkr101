# %%
import pandas as pd

# %%
df = pd.DataFrame(
    columns=["Name", "Age", "Height"],
)

df
# Out:
# Empty DataFrame
# Columns: [Name, Age, Height]
# Index: []

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: [Name, Age, Height]
# Index: []

# %%
df.loc[0] = ["Allen", 22, 175]

df
# Out:
#     Name  Age  Height
# 0  Allen   22     175

# %%
df.loc[1] = ["Jack", 25, 180]
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1   Jack   25     180

# %%
df["Age"][1] = 28
# Out:
# /var/folders/_k/k5dry95j0q5d35_9pn5d86vm0000gn/T/ipykernel_50320/2063534485.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df["Age"][1] = 28

# %%
df.loc[1, "Age"] = 28

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1   Jack   28     180

# %%
df["Weight"] = [75, 80]

# %%
df
# Out:
#     Name  Age  Height  Weight
# 0  Allen   22     175      75
# 1   Jack   28     180      80

# %%
df.drop("Weight", axis=1)
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1   Jack   28     180

# %%
df = df.drop("Weight", axis=1)
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1   Jack   28     180

# %%
df.drop(1)
# Out:
#     Name  Age  Height
# 0  Allen   22     175

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1   Jack   28     180

# %%
df = df.drop(1)
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175

# %%
df["Age"]
# Out:
# 0    22
# Name: Age, dtype: int64

# %%
"""
select
    age + 10
from user
"""
df["Age"] + 10
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175

# %%
df["Age"] = df["Age"] + 10
df
# Out:
#     Name  Age  Height
# 0  Allen   32     175

# %%
df2 = df

# %%
df2[0, "Age"] = 50
df2
# Out:
#     Name  Age  Height  (0, Age)
# 0  Allen   32     175        50

# %%
df
# Out:
#     Name  Age  Height  (0, Age)
# 0  Allen   32     175        50

# %%
df3 = df.copy()

# %%
df3.loc[0, "Age"] = 5
df3
# Out:
#     Name  Age  Height  (0, Age)
# 0  Allen    5     175        50

# %%
df
# Out:
#     Name  Age  Height  (0, Age)
# 0  Allen   32     175        50

# %%
df
# Out:
#     Name  Age  Height  (0, Age)
# 0  Allen   32     175        50

# %%
df.loc[:, "Age"]
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
df.loc[:, ["Age", "Name"]]
# Out:
#    Age   Name
# 0   32  Allen

# %%
df
# Out:
#     Name  Age  Height  (0, Age)
# 0  Allen   32     175        50

# %%
df.iloc[:, [0, 1]]
# Out:
#     Name  Age
# 0  Allen   32

# %%
data = [
    ["Allen", 22, 170],
    ["Ted", 25, 180],
]

pd.DataFrame(data=data)
# Out:
#        0   1    2
# 0  Allen  22  170
# 1    Ted  25  180
